# %%
## Import libraries
import pandas as pd
import requests
from zipfile import ZipFile
from remotezip import RemoteZip

# %%
# Efficiency Of Public Spending In Education, Health, And Infrastructure

## Dataset location: https://datacatalog.worldbank.org/dataset/efficiency-public-spending-education-health-and-infrastructure

file_name = "https://development-data-hub-s3-public.s3.amazonaws.com/ddhfiles/144175/paper-final-outpout_0_0.zip"

## First lets see all documents in zipfile

RemoteZip(file_name).namelist()
# Out:
# ['Paper Final Outpout/Annex 1 Education/',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/Excluding developed countries/',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/Excluding developed countries/Input oriented-excluding developed countries.do',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/Excluding developed countries/Output oriented-excluding developed countries.do',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/Including developed countries/',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/Including developed countries/Input oriented-including developed countries.do',
#  'Paper Final Outpout/Annex 1 Education/Dofiles/Single Input-Output/Including developed countries/Output oriented-including developed countries.do',
# ...

# %%
## Lets choose which data we need

file = RemoteZip(file_name).open('Paper Final Outpout/Annex 4 Excel dofiles/Working Dataset.xlsx').read()

## Read and made a dataframe

efficiency = pd.read_excel(file, sheet_name='Full Dataset')
efficiency.head(50)
# Out:
#     code  Region          Country name  Year Income group classification  \
# 0   code  region               country  year                      igroup
# 1    AGO     AFR                Angola  2006         Lower middle income
# 2    AGO     AFR                Angola  2007         Lower middle income
# 3    AGO     AFR                Angola  2008         Lower middle income
# 4    AGO     AFR                Angola  2009         Lower middle income
# 5    AGO     AFR                Angola  2010         Lower middle income
# 6    AGO     AFR                Angola  2011         Lower middle income
# 7    AGO     AFR                Angola  2012         Lower middle income
# 8    AGO     AFR                Angola  2013         Lower middle income
# 9    AGO     AFR                Angola  2014         Lower middle income
# 10   AGO     AFR                Angola  2015         Lower middle income
# 11   AGO     AFR                Angola  2016         Lower middle income
# ...

# %%
## Lets clean the dataframe

## see column names
efficiency.columns

## select columns not related to drop
columns_drop = ['Gross Primary School enrollment', 'Gross Secondary School enrollment', 'Net Primary School enrollment',
                'Net Secondary School enrollment', 'Literacy of Youth', 'Literacy of Adult',
                'first level complete (% of population ages 15+)','second level complete (% of population ages 15+)',
                'average years of school (ages 15+)', 'teacher per Pupils', 'Pupils per teacher',
                'Quality of primary education, 1-7 (best)', 'Primary education Net Enrollment, net %',
                'Secondary Education Gross Enrollment, gross %', 'Tertiary education enrollment, gross %',
                'Quality of the education system, 1-7 (best)', 'Quality of math and science education, 1-7 (best)',
                'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'PISA Reading scores', 'PISA Science scores',
                'PISA Mathematics scores', 'Population using improved drinking-water sources (%)',
                'Population using improved sanitation facilities (%)', 'GDP per capita, constant 2011 international $',
                'Public spending on Education (% of GDP) ', 'Public Spending on Education per capita, PPP $',
                'Quality of overall infrastructure, 1-7 (best)', 'Quality of roads, 1-7 (best)',
                'Quality of railroad infrastructure, 1-7 (best)', 'Quality of port infrastructure, 1-7 (best)',
                'Quality of air transport infrastructure, 1-7 (best)', 'A. Transport infrastructure',
                'Quality of electricity supply, 1-7 (best)', 'B. Electricity and telephony infrastructure',
                '2nd pillar: Infrastructure', 'A. Technological adoption', 'Innovation and sophistication factors',
                'GDP per capita (constant 2010 US$) [NY.GDP.MKTP.KD]', 'GDP (constant 2010 US$) [NY.GDP.MKTP.KD]',
                'GDP (current US$) [NY.GDP.MKTP.CD]',
                'National Currency per PPP dollar (Units National Currency per PPP dollar) [PPPEX]',
                'Private gross fixed capital formation, current prices (Billions National Currency) [NFIP]',
                'Public gross fixed capital formation, current prices (Billions National Currency) [NFIG]',
                'Population (Millions Persons) [LP]', 'Public investment spending per capita',
                'Private investment spending per capita', 'Total investment spending per capita',
                'GDP per capita, PPP (constant 2011 international $) [NY.GDP.PCAP.PP.KD]',
                'Government expenditure on education, total (% of GDP) [SE.XPD.TOTL.GD.ZS]',
                'Urban population (% of total) [SP.URB.TOTL.IN.ZS]', 'GINI index (World Bank estimate) [SI.POV.GINI]',
                'Net official development assistance and official aid received (current US$) [DT.ODA.ALLD.CD]',
                'Official exchange rate (LCU per US$, period average) [PA.NUS.FCRF]',
                'Net official development assistance and official aid received (constant 2013 US$) [DT.ODA.ALLD.KD]',
                'Revenue, excluding grants (current LCU) [GC.REV.XGRT.CN]',
                'PPP conversion factor, GDP (LCU per international $) [PA.NUS.PPP]',
                'Current education expenditure, total (% of total expenditure in public institutions) [SE.XPD.CTOT.ZS]',
                'Government expenditure on education, total (% of government expenditure) [SE.XPD.TOTL.GB.ZS]',
                'Compensation of employees (% of expense) [GC.XPN.COMP.ZS]',
                'General government final consumption expenditure (% of GDP) [NE.CON.GOVT.ZS]', 'Unnamed: 84',
                'Control of Corruption: Estimate [CC.EST]', 'Government Effectiveness: Estimate [GE.EST]',
                'Political Stability and Absence of Violence/Terrorism: Estimate [PV.EST]',
                'Regulatory Quality: Estimate [RQ.EST]', 'Rule of Law: Estimate [RL.EST]', 
                'Voice and Accountability: Estimate [VA.EST]']
    
efficiency = efficiency.drop(columns=columns_drop)  
efficiency
# Out:
#       code  Region Country name  Year Income group classification  \
# 0     code  region      country  year                      igroup
# 1      AGO     AFR       Angola  2006         Lower middle income
# 2      AGO     AFR       Angola  2007         Lower middle income
# 3      AGO     AFR       Angola  2008         Lower middle income
# 4      AGO     AFR       Angola  2009         Lower middle income
# ...    ...     ...          ...   ...                         ...
# 1932   ZWE     AFR     Zimbabwe  2012                  Low income
# 1933   ZWE     AFR     Zimbabwe  2013                  Low income
# 1934   ZWE     AFR     Zimbabwe  2014                  Low income
# 1935   ZWE     AFR     Zimbabwe  2015                  Low income
# 1936   ZWE     AFR     Zimbabwe  2016                  Low income
#
#      Life expectancy at birth Immunization DPT Immunization Measles  \
# 0                   lifebirth            imdpt                immea
# ...

# %%
#########################

# %%
# Health Equity And Financial Protection Indicators

## Dataset location: https://datacatalog.worldbank.org/dataset/hefpi

file_name = "https://databank.worldbank.org/data/download/HEFPI_Excel.ZIP"

## First lets see all documents in zipfile

RemoteZip(file_name).namelist()

## Lets choose which data we need

file = RemoteZip(file_name).open('HEFPIEXCEL.xlsx').read()

## Read and made a dataframe

equity_complete = pd.read_excel(file, sheet_name='Data')
equity_complete.head(50)
# Out:
#    Country Name Country Code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# 5   Afghanistan          AFG
# 6   Afghanistan          AFG
# 7   Afghanistan          AFG
# 8   Afghanistan          AFG
# 9   Afghanistan          AFG
# 10  Afghanistan          AFG
# 11  Afghanistan          AFG
# 12  Afghanistan          AFG
# 13  Afghanistan          AFG
# 14  Afghanistan          AFG
# 15  Afghanistan          AFG
# 16  Afghanistan          AFG
# 17  Afghanistan          AFG
# 18  Afghanistan          AFG
# 19  Afghanistan          AFG
# 20  Afghanistan          AFG
# 21  Afghanistan          AFG
# 22  Afghanistan          AFG
# 23  Afghanistan          AFG
# 24  Afghanistan          AFG
# 25  Afghanistan          AFG
# 26  Afghanistan          AFG
# 27  Afghanistan          AFG
# 28  Afghanistan          AFG
# 29  Afghanistan          AFG
# 30  Afghanistan          AFG
# ...

# %%
## Lets clean the dataframe

## see column names

equity_complete['Indicator Name'].unique()
# Out:
# array(['Acute respiratory infections treated (% of children under 5 with cough and rapid breathing)',
#        'Acute respiratory infections treated (% of children under 5 with cough and rapid breathing): Q1 (lowest)',
#        'Acute respiratory infections treated (% of children under 5 with cough and rapid breathing): Q2',
#        'Acute respiratory infections treated (% of children under 5 with cough and rapid breathing): Q3',
#        'Acute respiratory infections treated (% of children under 5 with cough and rapid breathing): Q4',
#        'Acute respiratory infections treated (% of children under 5 with cough and rapid breathing): Q5 (highest)',
#        'Births attended by skilled health staff (% of total)',
#        'Births attended by skilled health staff (% of total): Q1 (lowest)',
#        'Births attended by skilled health staff (% of total): Q2',
#        'Births attended by skilled health staff (% of total): Q3',
# ...

# %%
equity = equity_complete[
    (equity_complete['Indicator Name'] =='Acute respiratory infections treated (% of children under 5 with cough and rapid breathing)') |
    (equity_complete['Indicator Name'] =='Births attended by skilled health staff (% of total)') |
    (equity_complete['Indicator Name'] =='Blood pressure measured in last 12 months (% of population age 18+)') |
    (equity_complete['Indicator Name'] =='Blood sugar measured in last 5 years (% of population at risk of diabetes)') |
    (equity_complete['Indicator Name'] =='Cholesterol measured in last five years (% of population at risk of high cholesterol)') |
    (equity_complete['Indicator Name'] =='Condom use in last intercourse (% of females at risk population)') |
    (equity_complete['Indicator Name'] =='Contraceptive prevalence, modern methods (% of females ages 15-49)')|
    (equity_complete['Indicator Name'] =='Diarrhea treatment (% of children under 5 who received ORS)') |
    (equity_complete['Indicator Name'] =='High blood pressure or being treated for high blood pressure (% of adult population)') |
    (equity_complete['Indicator Name'] =='High cholesterol or on treatment for high cholesterol (% of adult population)') |
    (equity_complete['Indicator Name'] =='Immunization, full (% of children ages 15-23 months)') |
    (equity_complete['Indicator Name'] =='Immunization, measles (% of children ages 15-23 months)') | 
    (equity_complete['Indicator Name'] =='Impaired fasting glycaemia (% of adult population)') |
    (equity_complete['Indicator Name'] =='Inpatient care use in last 12 months (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Mammography in last 2 years, (% of females 50-69)') |
    (equity_complete['Indicator Name'] =='Mean BMI, adults (age 18+)') |
    (equity_complete['Indicator Name'] =='Mean BMI, female (age 18+)') |
    (equity_complete['Indicator Name'] =='Mean BMI, female (ages 15-49)') | 
    (equity_complete['Indicator Name'] =='Mean BMI, male (age 18+)') |
    (equity_complete['Indicator Name'] =='Mean cholesterol, adult population (mmol/L)') |
    (equity_complete['Indicator Name'] =='Mean diastolic blood pressure, adult population (mmHg)') |
    (equity_complete['Indicator Name'] =='Mean fasting blood glucose, adult population (mmol/L)') |
    (equity_complete['Indicator Name'] =='Mean height in meters, adults (age 18+)') |
    (equity_complete['Indicator Name'] =='Mean height in meters, female (age 18+)') |
    (equity_complete['Indicator Name'] =='Mean height in meters, female, (age 15-49)') | 
    (equity_complete['Indicator Name'] =='Mean height in meters, male (age 18+)') |
    (equity_complete['Indicator Name'] =='Mean household per capita out-of-pocket health spending ($ 2011 PPP)') |
    (equity_complete['Indicator Name'] =='Mean share of household consumption or income used on out-of-pocket health spending (%)') |
    (equity_complete['Indicator Name'] =='Mean systolic blood pressure, adult population (mmHg)') |
    (equity_complete['Indicator Name'] =='Mortality rate, infant (per 1,000 live births)') |
    (equity_complete['Indicator Name'] =='Mortality rate, under-5 (per 1,000)') |
    (equity_complete['Indicator Name'] =='Pap smear in last 5 years (% of females 30-49)') |
    (equity_complete['Indicator Name'] =='Pregnant women receiving prenatal care of at least four visits (% of pregnant women)') |
    (equity_complete['Indicator Name'] =='Prevalence of HIV, total (% of population ages 15-49)') |
    (equity_complete['Indicator Name'] =='Prevalence of obesity, BMI > 30 (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Prevalence of obesity, female, BMI > 30 (% of population 15-49)') |
    (equity_complete['Indicator Name'] =='Prevalence of obesity, female, BMI > 30 (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Prevalence of obesity, male, BMI > 30 (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Prevalence of overweight, BMI > 25 (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Prevalence of overweight, female, BMI > 25 (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Prevalence of overweight, female, BMI > 25 (% of population ages 15-49)') |
    (equity_complete['Indicator Name'] =='Prevalence of overweight, male, BMI > 25 (% of population 18+)') |
    (equity_complete['Indicator Name'] =='Prevalence of stunting, height for age (% of children under 5)') |
    (equity_complete['Indicator Name'] =='Prevalence of underweight, weight for age (% of children under 5)') | 
    (equity_complete['Indicator Name'] =='Proportion of population pushed below the $1.90 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure (%)') |
    (equity_complete['Indicator Name'] =='Proportion of population pushed below the $21.70 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure (%)') | 
    (equity_complete['Indicator Name'] =='Proportion of population pushed below the $3.20 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure (%)') |
    (equity_complete['Indicator Name'] =='Proportion of population pushed below the $5.50 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure (%)') |
    (equity_complete['Indicator Name'] =='Proportion of population pushed below the 60% median consumption poverty line by out-of-pocket health care expenditure (%)') | 
    (equity_complete['Indicator Name'] =='Proportion of population pushed by out-of-pocket health care expenditure below the societal poverty line, defined as the higher of the $1.90 ($ 2011 PPP) poverty line and a 50% of median consumption poverty line (%)') | 
    (equity_complete['Indicator Name'] =='Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)')|
    (equity_complete['Indicator Name'] =='Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)') |
    (equity_complete['Indicator Name'] =='Treated for high blood pressure (% of adult population)') |
    (equity_complete['Indicator Name'] =='Treated for raised blood glucose or diabetes (% of adult population)') |
    (equity_complete['Indicator Name'] =='Unmet need for contraception (% of females ages 15-49)') |
    (equity_complete['Indicator Name'] =='Use of insecticide-treated bed nets (% of under-5 population)')]

# %%
equity
# Out:
#       Country Name Country Code  \
# 0      Afghanistan          AFG
# 6      Afghanistan          AFG
# 12     Afghanistan          AFG
# 18     Afghanistan          AFG
# 28     Afghanistan          AFG
# ...            ...          ...
# 62025     Zimbabwe          ZWE
# 62031     Zimbabwe          ZWE
# 62037     Zimbabwe          ZWE
# 62043     Zimbabwe          ZWE
# 62049     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      Acute respiratory infections treated (% of chi...     HF.STA.ARIC.ZS
# 6      Births attended by skilled health staff (% of ...     HF.STA.BRTC.ZS
# 12     Blood pressure measured in last 12 months (% o...     HF.STA.BP18.ZS
# 18     Blood sugar measured in last 5 years (% of pop...     HF.STA.BLSG.ZS
# 28     Cholesterol measured in last five years (% of ...     HF.STA.CHOM.ZS
# ...                                                  ...                ...
# ...

# %%
#########################

# %%
# Health Nutrition And Population Statistics

## Dataset location: https://datacatalog.worldbank.org/dataset/health-nutrition-and-population-statistics

file_name = "https://databank.worldbank.org/data/download/hnp_stats_excel.zip"

## First lets see all documents in zipfile

RemoteZip(file_name).namelist()

## Lets choose which data we need

file = RemoteZip(file_name).open('HNP_StatsEXCEL.xlsx').read()

## Read and made a dataframe

nutrition = pd.read_excel(file, sheet_name='Data')
nutrition.head(50)
# Out:
#    Country Name Country Code  \
# 0    Arab World          ARB
# 1    Arab World          ARB
# 2    Arab World          ARB
# 3    Arab World          ARB
# 4    Arab World          ARB
# 5    Arab World          ARB
# 6    Arab World          ARB
# 7    Arab World          ARB
# 8    Arab World          ARB
# 9    Arab World          ARB
# 10   Arab World          ARB
# 11   Arab World          ARB
# 12   Arab World          ARB
# 13   Arab World          ARB
# 14   Arab World          ARB
# 15   Arab World          ARB
# 16   Arab World          ARB
# 17   Arab World          ARB
# 18   Arab World          ARB
# 19   Arab World          ARB
# 20   Arab World          ARB
# 21   Arab World          ARB
# 22   Arab World          ARB
# 23   Arab World          ARB
# 24   Arab World          ARB
# 25   Arab World          ARB
# 26   Arab World          ARB
# 27   Arab World          ARB
# 28   Arab World          ARB
# 29   Arab World          ARB
# 30   Arab World          ARB
# ...

# %%
## Lets clean the dataframe

## see column names

nutrition['Indicator Name'].unique()
# Out:
# array(['Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Adults (ages 15+) and children (0-14 years) living with HIV',
#        'Adults (ages 15+) and children (ages 0-14) newly infected with HIV',
#        'Adults (ages 15+) living with HIV',
#        'Adults (ages 15-49) newly infected with HIV',
#        'Age at first marriage, female', 'Age at first marriage, male',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old', 'Age dependency ratio, young',
#        'Age population, age 00, female, interpolated',
#        'Age population, age 00, male, interpolated',
#        'Age population, age 01, female, interpolated',
#        'Age population, age 01, male, interpolated',
#        'Age population, age 02, female, interpolated',
#        'Age population, age 02, male, interpolated',
#        'Age population, age 03, female, interpolated',
#        'Age population, age 03, male, interpolated',
# ...

# %%
#########################

# %%
# Health Nutrition And Population Statistics

## Dataset location: https://datacatalog.worldbank.org/dataset/health-nutrition-and-population-statistics-wealth-quintile

file_name = "https://databank.worldbank.org/data/download/hnpq_excel.zip"

## First lets see all documents in zipfile

RemoteZip(file_name).namelist()

## Lets choose which data we need

file = RemoteZip(file_name).open('HNPQEXCEL.xlsx').read()

## Read and made a dataframe

stats = pd.read_excel(file, sheet_name='Data')
stats.head(50)
# Out:
#    Country Name Country Code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# 5   Afghanistan          AFG
# 6   Afghanistan          AFG
# 7   Afghanistan          AFG
# 8   Afghanistan          AFG
# 9   Afghanistan          AFG
# 10  Afghanistan          AFG
# 11  Afghanistan          AFG
# 12  Afghanistan          AFG
# 13  Afghanistan          AFG
# 14  Afghanistan          AFG
# 15  Afghanistan          AFG
# 16  Afghanistan          AFG
# 17  Afghanistan          AFG
# 18  Afghanistan          AFG
# 19  Afghanistan          AFG
# 20  Afghanistan          AFG
# 21  Afghanistan          AFG
# 22  Afghanistan          AFG
# 23  Afghanistan          AFG
# 24  Afghanistan          AFG
# 25  Afghanistan          AFG
# 26  Afghanistan          AFG
# 27  Afghanistan          AFG
# 28  Afghanistan          AFG
# 29  Afghanistan          AFG
# 30  Afghanistan          AFG
# ...

# %%
## Lets clean the dataframe

## see column names

stats['Indicator Name'].unique()
# Out:
# array([' Total fertility rate (TFR) (births per woman): Q1 (lowest)',
#        ' Total fertility rate (TFR) (births per woman): Q2',
#        ' Total fertility rate (TFR) (births per woman): Q3',
#        ' Total fertility rate (TFR) (births per woman): Q4',
#        ' Total fertility rate (TFR) (births per woman): Q5 (highest)',
#        'Acceptability of media messages on family planning (% of women): Q1 (lowest)',
#        'Acceptability of media messages on family planning (% of women): Q2',
#        'Acceptability of media messages on family planning (% of women): Q3',
#        'Acceptability of media messages on family planning (% of women): Q4',
#        'Acceptability of media messages on family planning (% of women): Q5 (highest)',
#        'Antenatal care (any skilled personnel) (% of women with a birth): Q1 (lowest)',
#        'Antenatal care (any skilled personnel) (% of women with a birth): Q2',
# ...

# %%
#########################

# %%
# World Bank WDI 2.12 - Health Systems

## Dataset location: https://www.kaggle.com/danevans/world-bank-wdi-212-health-systems

#file_name = "https://www.kaggle.com/danevans/world-bank-wdi-212-health-systems?select=2.12_Health_systems.csv"

## Read and made a dataframe

systems = pd.read_csv('2.12_Health_systems.csv',sep=',')
systems.head(50)
# Out:
#               Country_Region   Province_State           World_Bank_Name  \
# 0                Afghanistan              NaN               Afghanistan
# 1                    Albania              NaN                   Albania
# 2                    Algeria              NaN                   Algeria
# 3                    Andorra              NaN                   Andorra
# 4                     Angola              NaN                    Angola
# 5        Antigua and Barbuda              NaN       Antigua and Barbuda
# 6                  Argentina              NaN                 Argentina
# 7                    Armenia              NaN                   Armenia
# 8                  Australia              NaN                 Australia
# 9                    Austria              NaN                   Austria
# 10                Azerbaijan              NaN                Azerbaijan
# 11                   Bahamas              NaN              Bahamas, The
# ...

# %%
#####################

# %%
## Lets create a excel with all dataframe info

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('pandas_multiple.xlsx', engine='xlsxwriter')

# Write each dataframe to a different worksheet.
efficiency.to_excel(writer, sheet_name='efficiency')
equity.to_excel(writer, sheet_name='equity')
nutrition.to_excel(writer, sheet_name='nutrition')
stats.to_excel(writer, sheet_name='stats')
systems.to_excel(writer, sheet_name='systems')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
